# %% [markdown]
# # Welcome
# This notebook shall answer assignment_1a question 4.
#
# # Table of Contents <a name="toc"></a>
#
# * [Imports](#imports)
# * [Global](#global)
# * [Helper Functions](#helper_functions)
# * [Question 3: Optimal Decay Parameter](#optimal_decay_parameter)
#     * [Model Parameters](#model_parameters)
#     * [Create the Model](#create_the_model)
#     * [Run the Model](#run_the_model)
#     * [Save Data Objects](#save_data_objects)
#     * [Plot Model Performance](#plot_model_performance)
#     * [Comparing Models](#comparing_models)
#     * [Eyeballing Decay Parameter](#eyeballing_decay_parameter)
# * [Conclusion](#conclusion)
#     * [Try Test Set](#try_test_set)

# %% [markdown]
# # Imports <a name="imports"></a>
# [Back to top](#toc)

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import json
import time

from tensorflow import keras
from tqdm.keras import TqdmCallback
from sklearn import preprocessing
from sklearn.model_selection import KFold, train_test_split

# %%
X_train = np.load('data/X_train.npy')
X_test = np.load('data/X_test.npy')
Y_train = np.load('data/Y_train.npy')
Y_test = np.load('data/Y_test.npy')
print("Data loaded")
# Out:
# Data loaded

# %% [markdown]
# # Global <a name="global"></a>
# [Back to top](#toc)

# %%
seed = 10
np.random.seed(seed)
tf.random.set_seed(seed)

cv_5fold = KFold(n_splits=5, random_state=seed, shuffle=False)
cv_5fold.get_n_splits(X_train)

# data objects
histories = {} 
times = {}
# Out:
# C:\Users\user\anaconda3\envs\cz4042_env\lib\site-packages\sklearn\model_selection\_split.py:297: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning

# %% [markdown]
# # Helper Functions <a name="helper_functions"></a>
# [Back to top](#toc)

# %% [markdown]
# ### plot_history_object()

# %%
def plot_history_object(histories, model_name, history_object):    
    plt.plot(histories[model_name][history_object], label='train_'+history_object)
    plt.plot(histories[model_name]['val_'+history_object], label='val_'+history_object)
    plt.ylabel(history_object)
    plt.xlabel('No. epoch')
    plt.legend(loc="center right")
    plt.show()

# %% [markdown]
# ### TimeHistory()

# %%
class TimeHistory(keras.callbacks.Callback):
    def on_train_begin(self, logs={}):
        self.times = []

    def on_epoch_begin(self, batch, logs={}):
        self.epoch_time_start = time.time()

    def on_epoch_end(self, batch, logs={}):
        self.times.append(time.time() - self.epoch_time_start)

# %% [markdown]
# ### histories_saver()

# %%
# filename like 'data/histories_q1.json'
def histories_saver(histories, filename):
    histories_json = {}
    for key in histories.keys():
        histories_json[key] = histories[key].history

    with open(filename, 'w') as file:
        json.dump(histories_json, file)

    print("All histories saved")

# %% [markdown]
# # Question 3: Optimal Decay Parameter  <a name="optimal_decay_parameter"></a>
# [Back to top](#toc)
#
# <i>Find the optimal number of hidden neurons for the 3-layer network designed in part (2).
#
# * a) Plot the cross-validation accuracies against the number of epochs for different number of hidden-layer neurons. Limit the search space of number of neurons to {5,10,15,20,25}.
# * b) Select the optimal number of neurons for the hidden layer. State the rationale for your selection.
# * c) Plot the train and test accuracies against epochs with the optimal number of neurons. </i>

# %% [markdown]
# ### Model Parameters <a name="model_parameters"></a>
# [Back to top](#toc)

# %%
num_neurons = 20 # from assignment_1a q3
num_classes = 3

weight_decay_parameters = [0, 10e-3, 10e-6, 10e-9, 10e-12]
regularizations = [keras.regularizers.l2(weight_decay_parameter) for weight_decay_parameter in weight_decay_parameters]

optimizer = 'sgd'
loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True)
metrics = ['accuracy', keras.metrics.SparseCategoricalCrossentropy(from_logits=True)]

epochs = 300 # from assignment_1a q1
learning_rate = 0.01
batch_size = 16 # from assignment_1a q2

# callbacks = [
#     TqdmCallback(verbose=1), 
#     tf.keras.callbacks.EarlyStopping(monitor='loss', patience=5),
#     time_callback
# ]

# times = time_callback.times

print("Model Parameters set")
# Out:
# Model Parameters set

# %% [markdown]
# ### Create the model <a name="create_the_model"></a>
# [Back to top](#toc)

# %%
def create_model(num_neurons, num_classes, regularization, optimizer, loss, metrics):
    model = keras.Sequential([
        keras.layers.Dense(num_neurons, activation='relu', kernel_regularizer=regularization, bias_regularizer=regularization),
        keras.layers.Dense(num_classes, activation='softmax')
    ])
    
    model.compile(optimizer=optimizer,
              loss=loss,
              metrics=metrics)
    
    print("Model created")
    return model

# %% [markdown]
# ### Run the model <a name="run_the_model"></a>
# [Back to top](#toc)

# %%
for decay_index, weight_decay_parameter in enumerate(weight_decay_parameters):    
    for index, (train_fold_index, val_fold_index) in enumerate(cv_5fold.split(X_train)):
        X_train_fold = X_train[train_fold_index]
        X_val_fold = X_train[val_fold_index]
        Y_train_fold = Y_train[train_fold_index]
        Y_val_fold = Y_train[val_fold_index]

        model = create_model(num_neurons, num_classes, regularizations[decay_index], optimizer, loss, metrics)

        time_callback = TimeHistory()
        callbacks = [TqdmCallback(verbose=1), time_callback]

        model_name = "weight_decay_parameter_" + str(weight_decay_parameter) + "_fold_" + str(index+1)
        
        print("Training ", model_name)

        histories[model_name] = model.fit(X_train_fold, Y_train_fold,
                                                                epochs=epochs,
                                                                verbose = 0,
                                                                batch_size=batch_size,
                                                                validation_data=(X_val_fold, Y_val_fold),
                                                                callbacks=callbacks)
        
        times[model_name] = time_callback.times
# Out:
# Model created
# ...
# Training  weight_decay_parameter_0_fold_1
# WARNING:tensorflow:Callbacks method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0004s vs `on_train_batch_begin` time: 0.0008s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0004s vs `on_train_batch_end` time: 0.0009s). Check your callbacks.
#
# Model created
# ...
# Training  weight_decay_parameter_0_fold_2
#
# Model created
# ...
# Training  weight_decay_parameter_0_fold_3
#
# Model created
# ...
# Training  weight_decay_parameter_0_fold_4
#
# Model created
# ...
# Training  weight_decay_parameter_0_fold_5
#
# Model created
# ...
# Training  weight_decay_parameter_0.01_fold_1
#
# Model created
# ...
# Training  weight_decay_parameter_0.01_fold_2
#
# Model created
# ...
# Training  weight_decay_parameter_0.01_fold_3
#
# Model created
# ...
# Training  weight_decay_parameter_0.01_fold_4
#
# Model created
# ...
# Training  weight_decay_parameter_0.01_fold_5
#
# ...

# %% [markdown]
# ### Save Data Objects <a name="save_data_objects"></a>
# [Back to top](#toc)

# %%
histories_saver(histories, "data/histories_q4.json")
# Out:
# All histories saved

# %%
np.save('data/times_q4', times)
print('All times saved')
# Out:
# All times saved

# %%
with open('data/histories_q4.json') as json_file:
    histories = json.load(json_file)
print('histories reloaded')

times = np.load('data/times_q4.npy', allow_pickle=True).item() 
print('times reloaded')
# Out:
# histories reloaded
# times reloaded

# %% [markdown]
# ### Plot Model Performance <a name="plot_model_performance"></a>
# [Back to top](#toc)

# %%
for model_name in histories.keys():
    print("Plotting model performance for ", model_name)
    for history_object in ['accuracy', 'loss', 'sparse_categorical_crossentropy']:
        plot_history_object(histories, model_name, history_object)
# Out:
# Plotting model performance for  weight_decay_parameter_0_fold_1
# Plotting model performance for  weight_decay_parameter_0_fold_2
# Plotting model performance for  weight_decay_parameter_0_fold_3
# Plotting model performance for  weight_decay_parameter_0_fold_4
# Plotting model performance for  weight_decay_parameter_0_fold_5
# Plotting model performance for  weight_decay_parameter_0.01_fold_1
# Plotting model performance for  weight_decay_parameter_0.01_fold_2
# Plotting model performance for  weight_decay_parameter_0.01_fold_3
# Plotting model performance for  weight_decay_parameter_0.01_fold_4
# Plotting model performance for  weight_decay_parameter_0.01_fold_5
# Plotting model performance for  weight_decay_parameter_1e-05_fold_1
# Plotting model performance for  weight_decay_parameter_1e-05_fold_2
# Plotting model performance for  weight_decay_parameter_1e-05_fold_3
# Plotting model performance for  weight_decay_parameter_1e-05_fold_4
# ...

# %% [markdown]
# ### Comparing Models <a name="comparing_models"></a>
# [Back to top](#toc)

# %%
ave_times = []
for weight_decay_parameter in weight_decay_parameters:
    total_time_batch = 0
    count = 0
    for index in range(5):
        weight_decay_parameter_times = times['weight_decay_parameter_' + str(weight_decay_parameter) + '_fold_' + str(index+1)]
        total_time_batch += np.sum(weight_decay_parameter_times)
        count += len(weight_decay_parameter_times)
    ave_times.append(total_time_batch/count)

print("ave_times: ", ave_times)
# Out:
# ave_times:  [0.0886493247350057, 0.07405291080474853, 0.06886236476898193, 0.07060433880488078, 0.0696241135597229]

# %%
df_ave_times = pd.DataFrame(ave_times, columns =['ave_time']) 
df_weight_decay_parameters = pd.DataFrame(weight_decay_parameters, columns =['weight_decay_parameters']) 
df_ave_times_weight_decay_parameters = pd.concat([df_weight_decay_parameters, df_ave_times], axis=1)

sns.barplot(data=df_ave_times_weight_decay_parameters, x="weight_decay_parameters", y="ave_time").set_title("weight_decay_parameter vs ave_time (per epoch)")
# Out:
# Text(0.5, 1.0, 'weight_decay_parameter vs ave_time (per epoch)')

# %%
ave_loss = []
ave_val_loss = []
ave_accuracy = []
ave_val_accuracy = []
ave_sparse_categorical_crossentropy = []
ave_val_sparse_categorical_crossentropy = []

for weight_decay_parameter in weight_decay_parameters:
    weight_decay_parameter_loss = []
    weight_decay_parameter_val_loss = []
    weight_decay_parameter_accuracy = []
    weight_decay_parameter_val_accuracy = []
    weight_decay_parameter_sparse_categorical_crossentropy = []
    weight_decay_parameter_val_sparse_categorical_crossentropy = []
    
    for index in range(5):
        history = histories['weight_decay_parameter_' + str(weight_decay_parameter) + '_fold_' + str(index+1)]

        weight_decay_parameter_loss.append(np.array(history['loss']))
        weight_decay_parameter_val_loss.append(np.array(history['val_loss']))
        weight_decay_parameter_accuracy.append(np.array(history['accuracy']))
        weight_decay_parameter_val_accuracy.append(np.array(history['val_accuracy']))
        weight_decay_parameter_sparse_categorical_crossentropy.append(np.array(history['sparse_categorical_crossentropy']))
        weight_decay_parameter_val_sparse_categorical_crossentropy.append(np.array(history['val_sparse_categorical_crossentropy']))
        
    ave_loss.append(np.mean(weight_decay_parameter_loss, axis=0))
    ave_val_loss.append(np.mean(weight_decay_parameter_val_loss, axis=0))
    ave_accuracy.append(np.mean(weight_decay_parameter_accuracy, axis=0))
    ave_val_accuracy.append(np.mean(weight_decay_parameter_val_accuracy, axis=0))
    ave_sparse_categorical_crossentropy.append(np.mean(weight_decay_parameter_sparse_categorical_crossentropy, axis=0))
    ave_val_sparse_categorical_crossentropy.append(np.mean(weight_decay_parameter_val_sparse_categorical_crossentropy, axis=0))

# %%
x = np.arange(1, 301)

for i in range(5):
    plt.plot(x, ave_val_loss[i], label='weight_decay_parameter '+str(weight_decay_parameters[i]))
    plt.ylabel("ave_val_loss")
    plt.xlabel("No. epoch")
    plt.legend(loc="center right")
plt.show()
    
for i in range(5):
    plt.plot(x, ave_val_accuracy[i], label='weight_decay_parameter '+str(weight_decay_parameters[i]))
    plt.ylabel("ave_val_accuracy")
    plt.xlabel("No. epoch")
    plt.legend(loc="center right")
plt.show()    

for i in range(5):
    plt.plot(x, ave_val_sparse_categorical_crossentropy[i], label='weight_decay_parameter '+str(weight_decay_parameters[i]))
    plt.ylabel("ave_val_sparse_categorical_crossentropy")
    plt.xlabel("No. epoch")
    plt.legend(loc="center right")    
plt.show()

# %% [markdown]
# ### Eyeballing Decay Parameter <a name="eyeballing_decay_parameter"></a>
# [Back to top](#toc)
#
# We can see from averaging the validation set values, that ```weight_decay_parameter = 1e-08``` has the best performance
#
# Let's take a slightly more mathematical approach and consider the incremental time gains gotten from the incremental gains in performance, using the best results of ```weight_decay_parameter = 1e-8``` as the baseline since it appears to be the best performer

# %%
df_incremental_time_gains = df_ave_times_weight_decay_parameters
df_incremental_time_gains['ave_time'] -= df_incremental_time_gains['ave_time'][3]
df_incremental_time_gains['ave_time'] = np.abs(df_incremental_time_gains['ave_time'])
df_incremental_time_gains
# Out:
#    weight_decay_parameters  ave_time
# 0             0.000000e+00  0.018045
# 1             1.000000e-02  0.003449
# 2             1.000000e-05  0.001742
# 3             1.000000e-08  0.000000
# 4             1.000000e-11  0.000980

# %%
incremental_ave_val_loss_gains = np.array(ave_val_loss).T.copy()
incremental_ave_val_accuracy_gains = np.array(ave_val_accuracy).T.copy()
incremental_ave_val_sparse_categorical_crossentropy_gains = np.array(ave_val_sparse_categorical_crossentropy).T.copy()

# %%
df_incremental_ave_val_loss_gains = pd.DataFrame(incremental_ave_val_loss_gains, columns =['decay=0', 'decay=10e-3', 'decay=10e-6', 'decay=10e-9', 'decay=10e-12']) 
df_incremental_ave_val_loss_gains_baseline = pd.DataFrame(df_incremental_ave_val_loss_gains['decay=10e-9'], columns=['decay=10e-9'])

for column in df_incremental_ave_val_loss_gains.columns:
    df_incremental_ave_val_loss_gains[column] = df_incremental_ave_val_loss_gains[column] - df_incremental_ave_val_loss_gains_baseline['decay=10e-9']

for column in df_incremental_ave_val_loss_gains.columns:
    plt.plot(x, df_incremental_ave_val_loss_gains[column], label=column)
    plt.ylabel("incremental_ave_val_loss_gains")
    plt.xlabel("No. epoch")
    plt.legend(loc="upper right")    
plt.show()

# %%
df_incremental_ave_val_accuracy_gains = pd.DataFrame(incremental_ave_val_accuracy_gains, columns =['decay=0', 'decay=10e-3', 'decay=10e-6', 'decay=10e-9', 'decay=10e-12']) 
df_incremental_ave_val_accuracy_gains_baseline = pd.DataFrame(df_incremental_ave_val_accuracy_gains['decay=10e-9'], columns=['decay=10e-9'])

for column in df_incremental_ave_val_accuracy_gains.columns:
    df_incremental_ave_val_accuracy_gains[column] = df_incremental_ave_val_accuracy_gains[column] - df_incremental_ave_val_accuracy_gains_baseline['decay=10e-9']

for column in df_incremental_ave_val_accuracy_gains.columns:
    plt.plot(x, df_incremental_ave_val_accuracy_gains[column], label=column)
    plt.ylabel("incremental_ave_val_accuracy_gains")
    plt.xlabel("No. epoch")
    plt.legend(loc="upper right")    
plt.show()

# %%
df_incremental_ave_val_sparse_categorical_crossentropy_gains = pd.DataFrame(incremental_ave_val_sparse_categorical_crossentropy_gains, columns =['decay=0', 'decay=10e-3', 'decay=10e-6', 'decay=10e-9', 'decay=10e-12']) 
df_incremental_ave_val_sparse_categorical_crossentropy_gains_baseline = pd.DataFrame(df_incremental_ave_val_sparse_categorical_crossentropy_gains['decay=10e-9'], columns=['decay=10e-9'])

for column in df_incremental_ave_val_sparse_categorical_crossentropy_gains.columns:
    df_incremental_ave_val_sparse_categorical_crossentropy_gains[column] = df_incremental_ave_val_sparse_categorical_crossentropy_gains[column] - df_incremental_ave_val_sparse_categorical_crossentropy_gains_baseline['decay=10e-9']

for column in df_incremental_ave_val_sparse_categorical_crossentropy_gains.columns:
    plt.plot(x, df_incremental_ave_val_sparse_categorical_crossentropy_gains[column], label=column)
    plt.ylabel("incremental_ave_val_sparse_categorical_crossentropy_gains")
    plt.xlabel("No. epoch")
    plt.legend(loc="upper right")    
plt.show()

# %% [markdown]
# # Conclusion <a name="conclusion"></a>
# [Back to top](#toc)
#
# > ```decay=10e-9``` is the optimal weight decay parameter to use
#
# It has the best performance, and the time it takes is very good compared to other decay parameters
#
# > use ```decay=10e-9``` for subsequent notebooks

# %% [markdown]
# ### Try Test Set <a name="try_test_set"></a>
# [Back to top](#toc)
#
# We shall use ```weight_decay_parameter=10e-9``` to check the performance of the model on the test set

# %%
weight_decay_parameter = 10e-9
regularization = keras.regularizers.l2(weight_decay_parameter)

test_histories = {}
test_times = {}

model = create_model(num_neuron, num_classes, regularization, optimizer, loss, metrics)

time_callback = TimeHistory()
callbacks = [TqdmCallback(verbose=1), time_callback]

model_name = "test_set"

print("Training ", model_name)

test_histories[model_name] = model.fit(X_test, Y_test,
                                        epochs=epochs,
                                        verbose = 0,
                                        batch_size=batch_size,
                                        callbacks=callbacks)

test_times[model_name] = time_callback.times
# Out:
# Model created
# ...
# Training  test_set

# %%
for history_object in ['loss', 'accuracy', 'sparse_categorical_crossentropy']:
    plt.plot(test_histories[model_name].history[history_object], label='test_'+history_object)
    plt.ylabel(history_object)
    plt.xlabel('No. epoch')
    plt.legend(loc="center right")
    plt.show()
