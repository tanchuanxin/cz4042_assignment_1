# %% [markdown]
# # assignment_1a question 4
#
# # Table of Contents <a name="toc"></a>
#
# * [Imports](#imports)
# * [Global](#global)
# * [Helper Functions](#helper_functions)
# * [Question 4: Optimal Decay Parameter](#optimal_decay_parameter)
#     * [Model Parameters](#model_parameters)
#     * [Create the Model](#create_the_model)
#     * [Run the Model](#run_the_model)
#     * [Save and Load Data Objects](#save_and_load_data_objects)
#     * [Plot Model Performance](#plot_model_performance)
#     * [Comparing Models](#comparing_models)
#     * [Eyeballing Decay Parameter](#eyeballing_decay_parameter)
#     * [Try Test Set](#try_test_set)
# * [Conclusion](#conclusion)

# %% [markdown]
# # Imports <a name="imports"></a>
# [Back to top](#toc)

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import json
import time

from tensorflow import keras
from tqdm.keras import TqdmCallback
from sklearn import preprocessing
from sklearn.model_selection import KFold, train_test_split

# %%
X_train = np.load('data/X_train.npy')
X_test = np.load('data/X_test.npy')
Y_train = np.load('data/Y_train.npy')
Y_test = np.load('data/Y_test.npy')
print("Data loaded")
# Out:
# Data loaded

# %% [markdown]
# # Global <a name="global"></a>
# [Back to top](#toc)

# %%
seed = 10
np.random.seed(seed)
tf.random.set_seed(seed)

cv_5fold = KFold(n_splits=5, random_state=seed)
cv_5fold.get_n_splits(X_train)

# data objects
histories = {} 
times = {}
# Out:
# C:\Users\user\anaconda3\envs\cz4042_env\lib\site-packages\sklearn\model_selection\_split.py:297: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning

# %% [markdown]
# # Helper Functions <a name="helper_functions"></a>
# [Back to top](#toc)

# %% [markdown]
# ### histories_saver()

# %%
# filename like 'data/histories_q1.json'
def histories_saver(histories, filename, already_json=False):
    histories_json = {}
    
    if already_json:
        histories_json = histories
    else:
        for key in histories.keys():
            histories_json[key] = histories[key].history

    with open(filename, 'w') as file:
        json.dump(histories_json, file)

    print("Histories saved")

# %% [markdown]
# ### histories_loader()

# %%
# filename like 'data/histories_q0.json'
def histories_loader(filename):
    with open(filename) as json_file:
        histories = json.load(json_file)
    print('Histories loaded')
    
    return histories

# %% [markdown]
# ### plot_history_object()

# %%
def plot_history_object(histories, model_name, history_object, plot_val=True):    
    plt.plot(histories[model_name][history_object], label='train_'+history_object)
    
    if plot_val:
        plt.plot(histories[model_name]['val_'+history_object], label='val_'+history_object)
    
    plt.title(history_object + ' against epochs')
    plt.ylabel(history_object)
    plt.xlabel('epochs')
    plt.legend(loc="center right")
    plt.show()

# %% [markdown]
# ### TestCallback()

# %%
# custom callback to evaluate the test set at each epoch
class TestCallback(keras.callbacks.Callback):
    def __init__(self, X_test, Y_test):
        self.X_test = X_test
        self.Y_test = Y_test

    def on_epoch_end(self, epoch, logs={}):
        loss, accuracy, sparse_categorical_crossentropy = self.model.evaluate(self.X_test, self.Y_test, verbose=0)
        
        histories_test['test_values']['accuracy'].append(accuracy)
        histories_test['test_values']['loss'].append(loss)
        histories_test['test_values']['sparse_categorical_crossentropy'].append(sparse_categorical_crossentropy)

# %% [markdown]
# ### TimeHistory()

# %%
class TimeHistory(keras.callbacks.Callback):
    def on_train_begin(self, logs={}):
        self.times = []

    def on_epoch_begin(self, batch, logs={}):
        self.epoch_time_start = time.time()

    def on_epoch_end(self, batch, logs={}):
        self.times.append(time.time() - self.epoch_time_start)

# %% [markdown]
# # Question 4: Optimal Decay Parameter  <a name="optimal_decay_parameter"></a>
# [Back to top](#toc)
#
# <i>4. Find the optimal decay parameter for the 3-layer network designed with optimal hidden neurons in part (3).
#
# * a) Plot cross-validation accuracies against the number of epochs for the 3-layer network for different values of decay parameters. Limit the search space of decay parameters to {0, 10−3, 10−6, 10−9, 10−12}.
# * b) Select the optimal decay parameter. State the rationale for your selection.
# * c) Plot the train and test accuracies against epochs for the optimal decay parameter.</i>

# %% [markdown]
# ### Model Parameters <a name="model_parameters"></a>
# [Back to top](#toc)

# %%
num_neurons = 10 # from assignment_1a_q3
num_classes = 3

weight_decay_parameters = [0, 10e-3, 10e-6, 10e-9, 10e-12]
regularizations = [keras.regularizers.l2(weight_decay_parameter) for weight_decay_parameter in weight_decay_parameters]

learning_rate= 0.01
optimizer = keras.optimizers.SGD(learning_rate=learning_rate)

loss = keras.losses.SparseCategoricalCrossentropy(from_logits=False)
metrics = ['accuracy', keras.metrics.SparseCategoricalCrossentropy(from_logits=False)]

validation_split = 0.3
epochs = 450 # from assignment_1a_q1
batch_size = 16 # from assignment_1a_q2

callbacks = [TqdmCallback(verbose=1)]

print("Model Parameters set")
# Out:
# ...
# Model Parameters set

# %% [markdown]
# ### Create the model <a name="create_the_model"></a>
# [Back to top](#toc)

# %%
def create_model(num_neurons, num_classes, regularization, optimizer, loss, metrics):
    model = keras.Sequential([
        keras.layers.Dense(num_neurons, activation='relu', kernel_regularizer=regularization),
        keras.layers.Dense(num_classes, activation='softmax')
    ])
    
    model.compile(optimizer=optimizer,
              loss=loss,
              metrics=metrics)
    
    print("Model created")
    return model

# %%
def fit_model_kfold(X_train, Y_train, X_val, Y_val, model_name, model, epochs, batch_size, callbacks):
    print("Training ", model_name)
    
    history = model.fit(X_train, Y_train,
                            validation_data=(X_val, Y_val),
                            epochs=epochs,
                            batch_size=batch_size,  
                            callbacks=callbacks,
                            verbose = 0)    
                            
    return model, history

# %%
def fit_model(X_train, Y_train, model_name, model, validation_split, epochs, batch_size, callbacks):
    print("Training ", model_name)
    
    history = model.fit(X_train, Y_train,
                            validation_split=0.3,
                            epochs=epochs,
                            batch_size=batch_size,  
                            callbacks=callbacks,
                            verbose = 0)    
                            
    return model, history

# %% [markdown]
# ### Run the model <a name="run_the_model"></a>
# [Back to top](#toc)

# %%
for index_decay, weight_decay_parameter in enumerate(weight_decay_parameters):    
    for index, (train_fold_index, val_fold_index) in enumerate(cv_5fold.split(X_train)):
        X_train_fold = X_train[train_fold_index]
        X_val_fold = X_train[val_fold_index]
        Y_train_fold = Y_train[train_fold_index]
        Y_val_fold = Y_train[val_fold_index]

        model = create_model(num_neurons, num_classes, regularizations[index_decay], optimizer, loss, metrics)
        model_name = "weight_decay_parameter_" + str(weight_decay_parameter) + "_fold_" + str(index+1)
        
        # create a new time_callback for every run
        callbacks = [TqdmCallback(verbose=1)]
        
        model_weight_decay_parameter_train, histories[model_name] = fit_model_kfold(X_train_fold, Y_train_fold, X_val_fold, Y_val_fold, model_name, model, epochs, batch_size, callbacks)
# Out:
# Model created
# ...
# Training  weight_decay_parameter_0_fold_1
#
#
# Model created
# ...
# Training  weight_decay_parameter_0_fold_2
#
# Model created
# ...
# Training  weight_decay_parameter_0_fold_3
#
# Model created
# ...
# Training  weight_decay_parameter_0_fold_4
#
# Model created
# ...
# Training  weight_decay_parameter_0_fold_5
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0000s vs `on_train_batch_end` time: 0.0010s). Check your callbacks.
#
# Model created
# ...
# Training  weight_decay_parameter_0.01_fold_1
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0000s vs `on_train_batch_end` time: 0.0010s). Check your callbacks.
#
# Model created
# ...
# Training  weight_decay_parameter_0.01_fold_2
#
# Model created
# ...
# Training  weight_decay_parameter_0.01_fold_3
#
# Model created
# ...
# Training  weight_decay_parameter_0.01_fold_4
#
# Model created
# ...
# Training  weight_decay_parameter_0.01_fold_5
# ...

# %% [markdown]
# ### Save and Load Data Objects <a name="save_and_load_data_objects"></a>
# [Back to top](#toc)

# %%
histories_saver(histories, "data/q4_histories.json")

histories = histories_loader("data/q4_histories.json")
# Out:
# Histories saved
# Histories loaded

# %% [markdown]
# ### Plot Model Performance <a name="plot_model_performance"></a>
# [Back to top](#toc)

# %%
for model_name in histories.keys():
    print('Model: ', model_name)
    for history_object in ['loss', 'accuracy', 'sparse_categorical_crossentropy']:
        plot_history_object(histories, model_name, history_object)
# Out:
# Model:  weight_decay_parameter_0_fold_1
# Model:  weight_decay_parameter_0_fold_2
# Model:  weight_decay_parameter_0_fold_3
# Model:  weight_decay_parameter_0_fold_4
# Model:  weight_decay_parameter_0_fold_5
# Model:  weight_decay_parameter_0.01_fold_1
# Model:  weight_decay_parameter_0.01_fold_2
# Model:  weight_decay_parameter_0.01_fold_3
# Model:  weight_decay_parameter_0.01_fold_4
# Model:  weight_decay_parameter_0.01_fold_5
# Model:  weight_decay_parameter_1e-05_fold_1
# Model:  weight_decay_parameter_1e-05_fold_2
# Model:  weight_decay_parameter_1e-05_fold_3
# Model:  weight_decay_parameter_1e-05_fold_4
# Model:  weight_decay_parameter_1e-05_fold_5
# Model:  weight_decay_parameter_1e-08_fold_1
# Model:  weight_decay_parameter_1e-08_fold_2
# Model:  weight_decay_parameter_1e-08_fold_3
# Model:  weight_decay_parameter_1e-08_fold_4
# Model:  weight_decay_parameter_1e-08_fold_5
# Model:  weight_decay_parameter_1e-11_fold_1
# Model:  weight_decay_parameter_1e-11_fold_2
# ...

# %% [markdown]
# ### Comparing Models <a name="comparing_models"></a>
# [Back to top](#toc)

# %% [markdown]
# > ### a) Plot cross-validation accuracies against the number of epochs for the 3-layer network for different values of decay parameters. Limit the search space of decay parameters to {0, 10−3, 10−6, 10−9, 10−12}.

# %% [markdown]
# ##### Average metrics per epoch

# %%
ave_loss = []
ave_val_loss = []
ave_accuracy = []
ave_val_accuracy = []
ave_ce = []
ave_val_ce = []

for weight_decay_parameter in weight_decay_parameters:
    wd_loss = []
    wd_val_loss = []
    wd_accuracy = []
    wd_val_accuracy = []
    wd_ce = []
    wd_val_ce = []
    
    for index in range(5):
        history = histories['weight_decay_parameter_' + str(weight_decay_parameter) + '_fold_' + str(index+1)]

        wd_loss.append(np.array(history['loss']))
        wd_val_loss.append(np.array(history['val_loss']))
        wd_accuracy.append(np.array(history['accuracy']))
        wd_val_accuracy.append(np.array(history['val_accuracy']))
        wd_ce.append(np.array(history['sparse_categorical_crossentropy']))
        wd_val_ce.append(np.array(history['val_sparse_categorical_crossentropy']))
        
    ave_loss.append(np.mean(wd_loss, axis=0))
    ave_val_loss.append(np.mean(wd_val_loss, axis=0))
    ave_accuracy.append(np.mean(wd_accuracy, axis=0))
    ave_val_accuracy.append(np.mean(wd_val_accuracy, axis=0))
    ave_ce.append(np.mean(wd_ce, axis=0))
    ave_val_ce.append(np.mean(wd_val_ce, axis=0))

print('Generated averages')
# Out:
# Generated averages

# %%
epochs_label = np.arange(1, epochs+1)

performance_metrics = [ave_loss, ave_val_loss, ave_accuracy, ave_val_accuracy, ave_ce, ave_val_ce]
performance_metrics_mapping = ['ave_loss', 'ave_val_loss', 'ave_accuracy', 'ave_val_accuracy', 'ave_ce', 'ave_val_ce']

for index, performance_metric in enumerate(performance_metrics):
    name = performance_metrics_mapping[index]
    
    for i in range(5):
        plt.plot(epochs_label, performance_metric[i], label='weight_decay_parameter '+str(weight_decay_parameters[i]))
        plt.title(name + " against epochs")
        plt.ylabel(name)
        plt.xlabel("epochs")
        plt.legend(loc="center right")
    plt.show()

# %% [markdown]
# ### Eyeballing Decay Parameter <a name="eyeballing_decay_parameter"></a>
# [Back to top](#toc)
#
# We can see from averaging the validation set values, that ```weight_decay_parameter = 0.01 = 10e-03``` has the best performance
#
# Let's take a slightly more mathematical approach and consider the incremental time gains gotten from the incremental gains in performance, using the best results of ```weight_decay_parameter = 10e-03``` as the baseline since it appears to be the best performer

# %%
incremental_ave_accuracy = np.array(ave_accuracy).T.copy()
incremental_ave_val_accuracy = np.array(ave_val_accuracy).T.copy()
incremental_ave_loss = np.array(ave_loss).T.copy()
incremental_ave_val_loss = np.array(ave_val_loss).T.copy()
incremental_ave_ce = np.array(ave_ce).T.copy()
incremental_ave_val_ce = np.array(ave_val_ce).T.copy()

# %%
incremental_metrics = [incremental_ave_accuracy, incremental_ave_val_accuracy, incremental_ave_loss, incremental_ave_val_loss, incremental_ave_ce, incremental_ave_val_ce]
incremental_metrics_mapping = ['incremental_ave_accuracy', 'incremental_ave_val_accuracy', 'incremental_ave_loss', 'incremental_ave_val_loss', 'incremental_ave_ce', 'incremental_ave_val_ce']

baseline_column = ['decay=10e-3']

# %%
for index, incremental_metric in enumerate(incremental_metrics):
    df_incremental_metric = pd.DataFrame(incremental_metric, columns =['decay=0', 'decay=10e-3', 'decay=10e-6', 'decay=10e-9', 'decay=10e-12']) 
    df_incremental_metric_baseline = pd.DataFrame(df_incremental_metric[baseline_column], columns=[baseline_column])
#     df_incremental_metric = df_incremental_metric[baseline_column].head()
    
    for column in df_incremental_metric.columns:
        df_incremental_metric[column] = df_incremental_metric[column] - df_incremental_metric_baseline[baseline_column]

    for column in df_incremental_metric.columns:
        plt.plot(epochs_label, df_incremental_metric[column], label=column)
        plt.title(incremental_metrics_mapping[index] + ' against epochs')
        plt.ylabel(incremental_metrics_mapping[index])
        plt.xlabel("epochs")
        plt.legend(loc="upper center")    
    plt.show()



# df_incremental_ave_val_loss_gains = pd.DataFrame(incremental_ave_val_loss_gains, columns =['decay=0', 'decay=10e-3', 'decay=10e-6', 'decay=10e-9', 'decay=10e-12']) 
# df_incremental_ave_val_loss_gains_baseline = pd.DataFrame(df_incremental_ave_val_loss_gains['decay=10e-9'], columns=['decay=10e-9'])

# for column in df_incremental_ave_val_loss_gains.columns:
#     df_incremental_ave_val_loss_gains[column] = df_incremental_ave_val_loss_gains[column] - df_incremental_ave_val_loss_gains_baseline['decay=10e-9']

# for column in df_incremental_ave_val_loss_gains.columns:
#     plt.plot(x, df_incremental_ave_val_loss_gains[column], label=column)
#     plt.ylabel("incremental_ave_val_loss_gains")
#     plt.xlabel("No. epoch")
#     plt.legend(loc="upper right")    
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-85a7d5759b0c> in <module>
#       5
#       6     for column in df_incremental_metric.columns:
# ----> 7         df_incremental_metric[column] = df_incremental_metric[column] - df_incremental_metric_baseline[baseline_column]
#       8
#       9     for column in df_incremental_metric.columns:
#
# ~\anaconda3\envs\cz4042_env\lib\site-packages\pandas\core\ops\__init__.py in f(self, other, axis, level, fill_value)
#     645         # TODO: why are we passing flex=True instead of flex=not special?
#     646         #  15 tests fail if we pass flex=not special instead
# --> 647         self, other = _align_method_FRAME(self, other, axis, flex=True, level=level)
#     648
#     649         if isinstance(other, ABCDataFrame):
#
# ...

# %%
# df_incremental_ave_val_accuracy_gains = pd.DataFrame(incremental_ave_val_accuracy_gains, columns =['decay=0', 'decay=10e-3', 'decay=10e-6', 'decay=10e-9', 'decay=10e-12']) 
# df_incremental_ave_val_accuracy_gains_baseline = pd.DataFrame(df_incremental_ave_val_accuracy_gains['decay=10e-9'], columns=['decay=10e-9'])

# for column in df_incremental_ave_val_accuracy_gains.columns:
#     df_incremental_ave_val_accuracy_gains[column] = df_incremental_ave_val_accuracy_gains[column] - df_incremental_ave_val_accuracy_gains_baseline['decay=10e-9']

# for column in df_incremental_ave_val_accuracy_gains.columns:
#     plt.plot(x, df_incremental_ave_val_accuracy_gains[column], label=column)
#     plt.ylabel("incremental_ave_val_accuracy_gains")
#     plt.xlabel("No. epoch")
#     plt.legend(loc="upper right")    
# plt.show()

# %%
# df_incremental_ave_val_sparse_categorical_crossentropy_gains = pd.DataFrame(incremental_ave_val_sparse_categorical_crossentropy_gains, columns =['decay=0', 'decay=10e-3', 'decay=10e-6', 'decay=10e-9', 'decay=10e-12']) 
# df_incremental_ave_val_sparse_categorical_crossentropy_gains_baseline = pd.DataFrame(df_incremental_ave_val_sparse_categorical_crossentropy_gains['decay=10e-9'], columns=['decay=10e-9'])

# for column in df_incremental_ave_val_sparse_categorical_crossentropy_gains.columns:
#     df_incremental_ave_val_sparse_categorical_crossentropy_gains[column] = df_incremental_ave_val_sparse_categorical_crossentropy_gains[column] - df_incremental_ave_val_sparse_categorical_crossentropy_gains_baseline['decay=10e-9']

# for column in df_incremental_ave_val_sparse_categorical_crossentropy_gains.columns:
#     plt.plot(x, df_incremental_ave_val_sparse_categorical_crossentropy_gains[column], label=column)
#     plt.ylabel("incremental_ave_val_sparse_categorical_crossentropy_gains")
#     plt.xlabel("No. epoch")
#     plt.legend(loc="lower right")    
# plt.show()

# %% [markdown]
# > ### b) Select the optimal decay parameter. State the rationale for your selection

# %% [markdown]
# > ```num_neurons=10``` is the more superior configuration
#
# After plotting the incremental changes, we can see that ```num_neurons=10``` has lower validation losses and higher validation accuracy than ```num_neurons=20```

# %% [markdown]
# ### Try Test Set <a name="try_test_set"></a>
# [Back to top](#toc)
#
# We shall use ```weight_decay_parameter=10e-9``` to check the performance of the model on the test set

# %%
# the optimized parameter and custome callback
weight_decay_parameter = 
regularization = keras.regularizers.l2(weight_decay_parameter)

callbacks = [TqdmCallback(verbose=1), TestCallback(X_test, Y_test)] 

# the history object to keep performance of X_test Y_test from hinal model
histories_test = {
    'test_values': {
        'loss': [],
        'accuracy': [],
        'sparse_categorical_crossentropy': []
    }
}

# the history object to keep performance of X_train Y_train from final model
histories_final = {}

# %%
model = create_model(num_neurons, num_classes, regularization, optimizer, loss, metrics)
model_name = 'train_values'
model_convergence_test, histories_final[model_name] = fit_model(X_train, Y_train, model_name, model, validation_split, epochs, batch_size, callbacks)

# the history
histories_saver(histories_final, "data/q4_histories_final.json")
histories_final = histories_loader("data/q4_histories_final.json")

histories_final['test_values'] = histories_test['test_values']

histories_saver(histories_final, "data/q4_histories_final.json", already_json=True)
histories_final = histories_loader("data/q4_histories_final.json")

# %% [markdown]
# > ### c) Plot the train and test accuracies against epochs for the optimal decay parameter.

# %%
for history_object in ['loss', 'accuracy', 'sparse_categorical_crossentropy']:
    for model_name in histories_final.keys():
        plt.plot(histories_final[model_name][history_object], label=model_name)

    plt.title(history_object + ' against epochs')
    plt.ylabel(history_object)
    plt.xlabel('epochs')
    plt.legend(loc="center right")
    plt.show()

# %%
# weight_decay_parameter = 10e-9
# regularization = keras.regularizers.l2(weight_decay_parameter)

# test_histories = {}
# test_times = {}

# model = create_model(num_neuron, num_classes, regularization, optimizer, loss, metrics)

# time_callback = TimeHistory()
# callbacks = [TqdmCallback(verbose=1), time_callback]

# model_name = "test_set"

# print("Training ", model_name)

# test_histories[model_name] = model.fit(X_test, Y_test,
#                                         epochs=epochs,
#                                         verbose = 0,
#                                         batch_size=batch_size,
#                                         callbacks=callbacks)

# test_times[model_name] = time_callback.times
# Out:
# Model created
# ...
# Training  test_set

# %%
# for history_object in ['loss', 'accuracy', 'sparse_categorical_crossentropy']:
#     plt.plot(test_histories[model_name].history[history_object], label='test_'+history_object)
#     plt.ylabel(history_object)
#     plt.xlabel('No. epoch')
#     plt.legend(loc="center right")
#     plt.show()

# %% [markdown]
# # Conclusion <a name="conclusion"></a>
# [Back to top](#toc)
#
# > ```decay=10e-9``` is the optimal weight decay parameter to use
#
# It has the best performance, and the time it takes is very good compared to other decay parameters
#
# > use ```decay=10e-9``` for subsequent notebooks
