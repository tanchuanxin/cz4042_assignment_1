# %% [markdown]
# # Welcome

# %% [markdown]
# This notebook shall answer assignment_1a question 1.
#
# # Table of Contents <a name="toc"></a>
#
# * [Imports](#imports)
# * [Global](#global)
# * [Helper Functions](#helper_functions)
# * [Question 1: Convergence](#convergence)
#     * [Model Parameters](#model_parameters)
#     * [Create the Model](#create_the_model)
#     * [Run the Model](#run_the_model)
#     * [Save Data Objects](#save_data_objects)
#     * [Plot Model Performance](#plot_model_performance)
#     * [Comparing Models](#comparing_models)
#     * [Eyeballing Convergence](#eyeballing_convergence)
# * [Conclusion](#conclusion)

# %% [markdown]
# # Imports <a name="imports"></a>
# [Back to top](#toc)

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import json

from tensorflow import keras
from tqdm.keras import TqdmCallback
from sklearn import preprocessing
from sklearn.model_selection import train_test_split

# %%
X_train = np.load('data/X_train.npy')
X_test = np.load('data/X_test.npy')
Y_train = np.load('data/Y_train.npy')
Y_test = np.load('data/Y_test.npy')
print("Data loaded")
# Out:
# Data loaded

# %% [markdown]
# # Global <a name="global"></a>
# [Back to top](#toc)

# %%
seed = 10
np.random.seed(seed)
tf.random.set_seed(seed)

# data objects
histories = {}

# %% [markdown]
# # Helper Functions <a name="helper_functions"></a>
# [Back to top](#toc)

# %% [markdown]
# ### plot_history_object()

# %%
def plot_history_object(histories, model_name, history_object):    
    plt.plot(histories[model_name][history_object], label='train_'+history_object)
    plt.plot(histories[model_name]['val_'+history_object], label='val_'+history_object)
    plt.ylabel(history_object)
    plt.xlabel('No. epoch')
    plt.legend(loc="center right")
    plt.show()

# %% [markdown]
# ### histories_saver()

# %%
# filename like 'data/histories_q1.json'
def histories_saver(histories, filename):
    histories_json = {}
    for key in histories.keys():
        histories_json[key] = histories[key].history

    with open(filename, 'w') as file:
        json.dump(histories_json, file)

    print("Histories saved")

# %% [markdown]
# # Question 1: Convergence  <a name="convergence"></a>
# [Back to top](#toc)

# %% [markdown]
# <i>Design a feedforward neural network which consists of an input layer, one hidden layer of 10 neurons with ReLU activation function, and an output softmax layer. Assume a learning rate 𝛼 = 0.01, L2 regularization with weight decay parameter 𝛽 = 10−6, and batch size = 32. Use appropriate scaling of input features.
#
# * a) Use the training dataset to train the model and plot accuracies on training and testing data against training epochs.
# * b) State the approximate number of epochs where the test error begin to converge.</i>

# %% [markdown]
# ### Model Parameters <a name="model_parameters"></a>
# [Back to top](#toc)

# %%
num_neurons = 10
num_classes = 3

weight_decay_parameter = 10e-6
regularization = keras.regularizers.l2(weight_decay_parameter)

optimizer = 'sgd'
loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True)
metrics = ['accuracy', keras.metrics.SparseCategoricalCrossentropy(from_logits=True)]

epochs = 5000
learning_rate = 0.01
batch_size = 32

# callbacks = [TqdmCallback(verbose=1)]
# callbacks = [TqdmCallback(verbose=1), tf.keras.callbacks.EarlyStopping(monitor='loss', patience=10)]

print("Model Parameters set")
# Out:
# Model Parameters set

# %% [markdown]
# ### Create the model <a name="create_the_model"></a>
# [Back to top](#toc)

# %%
def create_model(num_neurons, num_classes, regularization, optimizer, loss, metrics):
    model = keras.Sequential([
        keras.layers.Dense(num_neurons, activation='relu', kernel_regularizer=regularization, bias_regularizer=regularization),
        keras.layers.Dense(num_classes, activation='softmax')
    ])
    
    model.compile(optimizer=optimizer,
              loss=loss,
              metrics=metrics)
    
    print("Model created")
    return model

# %% [markdown]
# ### Run the model <a name="run_the_model"></a>
# [Back to top](#toc)

# %%
model = create_model(num_neurons, num_classes, regularization, optimizer, loss, metrics)

callbacks = [TqdmCallback(verbose=1)]
model_name = 'convergence_test_1'

histories[model_name] = model.fit(X_train, Y_train,
                                        epochs=epochs,
                                        verbose = 0,
                                        batch_size=batch_size,
                                        validation_data=(X_test, Y_test),
                                        callbacks=callbacks)
# Out:
# Model created
# ...

# %%
model = create_model(num_neurons, num_classes, regularization, optimizer, loss, metrics)

callbacks = [TqdmCallback(verbose=1), tf.keras.callbacks.EarlyStopping(monitor='loss', patience=5)]
model_name = 'convergence_test_2'

histories[model_name] = model.fit(X_train, Y_train,
                                        epochs=epochs,
                                        verbose = 0,
                                        batch_size=batch_size,
                                        validation_data=(X_test, Y_test),
                                        callbacks=callbacks)
# Out:
# Model created
# ...

# %%
model = create_model(num_neurons, num_classes, regularization, optimizer, loss, metrics)

callbacks = [TqdmCallback(verbose=1), tf.keras.callbacks.EarlyStopping(monitor='loss', patience=10)]
model_name = 'convergence_test_3'

histories[model_name] = model.fit(X_train, Y_train,
                                        epochs=epochs,
                                        verbose = 0,
                                        batch_size=batch_size,
                                        validation_data=(X_test, Y_test),
                                        callbacks=callbacks)
# Out:
# Model created
# ...

# %% [markdown]
# ### Save Data Objects <a name="save_data_objects"></a>
# [Back to top](#toc)

# %%
histories_saver(histories, "data/histories_q1.json")
# Out:
# Histories saved

# %%
with open('data/histories_q1.json') as json_file:
    histories = json.load(json_file)
print('histories reloaded')
# Out:
# histories reloaded

# %% [markdown]
# ### Plot Model Performance <a name="plot_model_performance"></a>
# [Back to top](#toc)

# %%
model_name = 'convergence_test_1'
for history_object in ['accuracy', 'loss', 'sparse_categorical_crossentropy']:
    plot_history_object(histories, model_name, history_object)

# %%
model_name = 'convergence_test_2'
for history_object in ['accuracy', 'loss', 'sparse_categorical_crossentropy']:
    plot_history_object(histories, model_name, history_object)

# %%
model_name = 'convergence_test_3'
for history_object in ['accuracy', 'loss', 'sparse_categorical_crossentropy']:
    plot_history_object(histories, model_name, history_object)

# %% [markdown]
# ### Comparing Models <a name="comparing_models"></a>
# [Back to top](#toc)

# %% [markdown]
# * <i>No early stopping - 5000 epochs</i>
#
# loss=0.591, accuracy=0.965, sparse_categorical_crossentropy=0.591, val_loss=0.625, val_accuracy=0.926, val_sparse_categorical_crossentropy=0.625
#
# * <i>Early stopping - patience 5, 1767 epochs</i>
#
# loss=0.618, accuracy=0.942, sparse_categorical_crossentropy=0.618, val_loss=0.638, val_accuracy=0.911, val_sparse_categorical_crossentropy=0.637
#
# * <i>Early stopping - patience 10, 4482 epochs</i>
#
# loss=0.618, accuracy=0.942, sparse_categorical_crossentropy=0.618, val_loss=0.638, val_accuracy=0.911, val_sparse_categorical_crossentropy=0.637

# %% [markdown]
# ### Eyeballing Convergence <a name="eyeballing_convergence"></a>
# [Back to top](#toc)
#
# Only the patience was varied for these three models. Just by eyeballing these metrics produced by the three different models, it appears that the second model, ```convergence_test_2``` yielded a good compromise between correctness of model and time taken to run the training (in terms of epochs).

# %%
for epoch in [200, 250, 300, 500, 750]:
    print("\npercentage_change from epoch ", epoch, " onwards")
    for history_object in ['accuracy', 'loss', 'sparse_categorical_crossentropy']:
        epoch_intermediate = histories['convergence_test_2']['val_'+history_object][epoch]
        epoch_last = histories['convergence_test_2']['val_'+history_object][-1]

        percentage_change = (epoch_last - epoch_intermediate) / epoch_intermediate * 100

        print(history_object, ": ", percentage_change, "%")
# Out:
# percentage_change from epoch  200  onwards
# accuracy :  1.929822232217668 %
# loss :  -3.344327937753272 %
# sparse_categorical_crossentropy :  -3.378195020516286 %
#
# percentage_change from epoch  250  onwards
# accuracy :  1.929822232217668 %
# loss :  -3.0154641558239543 %
# sparse_categorical_crossentropy :  -3.0479860309707747 %
#
# percentage_change from epoch  300  onwards
# accuracy :  2.1089636451904035 %
# loss :  -2.8096628106674912 %
# sparse_categorical_crossentropy :  -2.8409975845309665 %
#
# percentage_change from epoch  500  onwards
# accuracy :  1.7513150713486771 %
# loss :  -2.3196405011882777 %
# sparse_categorical_crossentropy :  -2.3467907450474956 %
#
# percentage_change from epoch  750  onwards
# accuracy :  0.8680563349633335 %
# loss :  -1.5913992696781596 %
# sparse_categorical_crossentropy :  -1.6134388519263 %

# %% [markdown]
# Further inspecting the accuracy, loss and sparse_categorical_crossentropy graphs of ```convergence_test_2```, the values after epoch 300 are quite similar, with a <3% difference between final epoch and the 300th epoch

# %% [markdown]
# # Conclusion <a name="conclusion"></a>
# [Back to top](#toc)
#
# 300 epochs appears to be sufficient to get a reasonable convergence for training
